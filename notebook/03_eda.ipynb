# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
# Caminhos padrões para os arquivos e pastas
caminho_processed = "../dados/processed"
caminho_gold = "../dados/gold"

df_analitico = pd.read_parquet(os.path.join(caminho_gold, "df_gold.parquet"))

# %%
# Visualização das colunas de dados 'float' para somente 2 casas decimais
pd.set_option('display.float_format', '{:,.2f}'.format)

# %% [markdown]
# # Criação de novas Features

# %%
# --- RENTABILIDADE ---
# ROE (Return on Equity)
df_analitico['kpi_roe'] = df_analitico['lucro_liquido'] / df_analitico['patrimonio_liquido']
# ROA (Return on Asset)
df_analitico['kpi_roa'] = df_analitico['lucro_liquido'] / df_analitico['ativo_total']

# --- QUALIDADE ---
# Dependência de "Outras Receitas".
# Se o banco depende muito de receitas não-operacionais, isso é não recorrente.
# Fórmula: Outras Receitas / (Total de Receitas Operacionais)
df_analitico['receita_total_estimada'] = df_analitico['resultado_intermediacao'] + df_analitico['outras_receitas_despesas']

df_analitico['kpi_qualidade_lucro'] = (df_analitico['outras_receitas_despesas'] + df_analitico['Resultado de Participações (t)']) / df_analitico['receita_total_estimada']

# --- VOLUMETRIA ---
# Tamanho do Banco (Log) para separar Pequenos de Gigantes
df_analitico['tamanho_log'] = np.log10(df_analitico['ativo_total'])

# Taxa média (Yield)
df_analitico['yield_carteira'] = df_analitico['Rendas de Operações de Crédito (c)'] / df_analitico['carteira_credito']
df_analitico['yield_carteira'] = df_analitico['yield_carteira'].replace([np.inf, -np.inf], np.nan)

df_analitico['custo_funding'] = (df_analitico['Despesa_Captacao_Total'] * -1) / df_analitico['captacoes']
# Custo Implícito = Quanto pagou de juros / Quanto tinha de dívida
df_analitico['taxa_funding_implicita'] = df_analitico['custo_funding'] / df_analitico['captacoes']

df_analitico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21585 entries, 150406 to 171990
# Data columns (total 75 columns):
#  #   Column                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                              --------------  -----
#  0   instituicao                                                                                         21585 non-null  string
#  1   data_base                                                                                           21585 non-null  datetime64[ns]
#  2   codigo_bacen                                                                                        21585 non-null  Int64
#  3   conglomerado                                                                                        21585 non-null  object
#  4   tcb                                                                                                 21585 non-null  category
#  5   tc                                                                                                  21585 non-null  Int64
#  6   ti                                                                                                  21585 non-null  Int64
#  7   cidade                                                                                              21585 non-null  string
#  8   uf                                                                                                  21585 non-null  category
#  9   ativo_total                                                                                         21452 non-null  float64
#  10  captacoes                                                                                           21452 non-null  float64
#  11  patrimonio_liquido                                                                                  21452 non-null  float64
#  12  lucro_liquido                                                                                       21452 non-null  float64
#  13  numero_agencias                                                                                     21585 non-null  int64
#  14  numero_postos_atendimento                                                                           21585 non-null  int64
#  15  carteira_credito                                                                                    21452 non-null  float64
#  16  passivel_exigivel                                                                                   21452 non-null  float64
#  17  Conglomerado Financeiro                                                                             21585 non-null  object
#  18  Rendas de Operações de Crédito (a1)                                                                 18334 non-null  float64
#  19  Rendas de Operações de Arrendamento Mercantil (a2)                                                  21452 non-null  float64
#  20  Rendas de Operações com TVM (a3)                                                                    18334 non-null  float64
#  21  Rendas de Operações com Instrumentos Financeiros Derivativos (a4)                                   18334 non-null  float64
#  22  Resultado de Operações de Câmbio (a5)                                                               18334 non-null  float64
#  23  Rendas de Aplicações Compulsórias (a6)                                                              18334 non-null  float64
#  24  Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)                  18334 non-null  float64
#  25  Despesas de Obrigações por Empréstimos e Repasses (b2)                                              18334 non-null  float64
#  26  Despesas de Operações de Arrendamento Mercantil (b3)                                                18334 non-null  float64
#  27  Resultado de Operações de Câmbio (b4)                                                               18334 non-null  float64
#  28  Resultado de Provisão para Créditos de Difícil Liquidação (b5)                                      18334 non-null  float64
#  29  Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)                         18334 non-null  float64
#  30  Resultado de Intermediação Financeira (c) = (a) + (b)                                               18334 non-null  float64
#  31  Rendas de Prestação de Serviços (d1)                                                                18334 non-null  float64
#  32  Rendas de Tarifas Bancárias (d2)                                                                    18334 non-null  float64
#  33  Despesas de Pessoal (d3)                                                                            18334 non-null  float64
#  34  Despesas Administrativas (d4)                                                                       18334 non-null  float64
#  35  Despesas Tributárias (d5)                                                                           18334 non-null  float64
#  36  Resultado de Participações (d6)                                                                     18334 non-null  float64
#  37  Outras Receitas Operacionais (d7)                                                                   18334 non-null  float64
#  38  Outras Despesas Operacionais (d8)                                                                   18334 non-null  float64
#  39  Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)  18334 non-null  float64
#  40  Resultado Operacional (e) = (c) + (d)                                                               18334 non-null  float64
#  41  Resultado Não Operacional (f)                                                                       18334 non-null  float64
#  42  Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)                                 18334 non-null  float64
#  43  Imposto de Renda e Contribuição Social (h)                                                          18334 non-null  float64
#  44  Participação nos Lucros (i)                                                                         18334 non-null  float64
#  45  Lucro Líquido (j) = (g) + (h) + (i)                                                                 18334 non-null  float64
#  46  Rendas de Títulos e Valores Mobiliários (b)                                                         21452 non-null  float64
#  47  Rendas de Operações de Crédito (c)                                                                  21452 non-null  float64
#  48  Resultado com Perda Esperada (f)                                                                    21452 non-null  float64
#  49  Despesa de Juros com Captações (g1)                                                                 21452 non-null  float64
#  50  Resultado com Derivativos (i)                                                                       21452 non-null  float64
#  51  resultado_intermediacao                                                                             21452 non-null  float64
#  52  Rendas de Tarifas Bancárias (m)                                                                     21452 non-null  float64
#  53  Outras Rendas de Prestação de Serviços (n)                                                          21452 non-null  float64
#  54  Despesas de Pessoal (o)                                                                             21452 non-null  float64
#  55  Despesas Administrativas (p)                                                                        21452 non-null  float64
#  56  Despesas Tributárias (s)                                                                            21452 non-null  float64
#  57  Resultado de Participações (t)                                                                      21452 non-null  float64
#  58  Outras Receitas (u)                                                                                 21452 non-null  float64
#  59  Outras Despesas (v)                                                                                 21452 non-null  float64
#  60  outras_receitas_despesas                                                                            21452 non-null  float64
#  61  resultado_antes_impostos                                                                            21452 non-null  float64
#  62  impostos_ir_csll                                                                                    21452 non-null  float64
#  63  participacoes_lucro                                                                                 21452 non-null  float64
#  64  Despesa_Captacao_Total                                                                              21452 non-null  float64
#  65  cidade_bas                                                                                          9897 non-null   category
#  66  indice_basileia                                                                                     9628 non-null   float64
#  67  kpi_roe                                                                                             21450 non-null  float64
#  68  kpi_roa                                                                                             21451 non-null  float64
#  69  receita_total_estimada                                                                              21452 non-null  float64
#  70  kpi_qualidade_lucro                                                                                 21432 non-null  float64
#  71  tamanho_log                                                                                         21452 non-null  float64
#  72  yield_carteira                                                                                      16303 non-null  float64
#  73  custo_funding                                                                                       15239 non-null  float64
#  74  taxa_funding_implicita                                                                              15239 non-null  float64
# dtypes: Int64(3), category(3), datetime64[ns](1), float64(62), int64(2), object(2), string(2)
# memory usage: 12.2+ MB
# c:\Users\Thiag\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#Código para auxiliar a encontrar as intituições. Pelo fato de ter várias no conglomerado financeiro
filtro_nome = df_analitico['instituicao'].str.contains('BANCO MÁXIMA S.A.', case=False, na=False)

bancosss = df_analitico[filtro_nome]

resultado = bancosss[['data_base','instituicao','ativo_total']]

resultado
# Out:
# Empty DataFrame
# Columns: [data_base, instituicao, ativo_total]
# Index: []

# %%
bancos_comparacao = [
    # Varejo e Consignado
    'BANCO PAN S.A.',
    'BANCO BMG S.A.',
    'BANCO MERCANTIL DO BRASIL S.A.',
    'BANCO AGIBANK S.A.',
    'BRB - BANCO DE BRASILIA S.A.',
    'BANCO DAYCOVAL S.A.',
    # Middle Market e Atacado (Concorrentes PJ do Master)
    'BANCO PINE S.A.',
    'BANCO SOFISA S.A.',
    'BANCO FIBRA S.A.',
    'BANCO ABC BRASIL S.A.',
    # Benchmarks de Nicho e Risco
    'OMNI BANCO S.A.',
    'PARANÁ BANCO S.A.',
    # Digital e Investment Banking
    'BANCO INTER S.A.'
]

bancos = [
    'BANCO MASTER S/A',
    'BANCO PAN S.A.',
    'BANCO BMG S.A.',
    'BANCO MERCANTIL DO BRASIL S.A.',
    'BANCO AGIBANK S.A.',
    'BRB - BANCO DE BRASILIA S.A.',
    'BANCO DAYCOVAL S.A.',
    'BANCO PINE S.A.',
    'BANCO SOFISA S.A.',
    'BANCO FIBRA S.A.',
    'BANCO ABC BRASIL S.A.',
    'OMNI BANCO S.A.',
    'PARANÁ BANCO S.A.',
    'BANCO INTER S.A.'
]

# %% [markdown]
# # **Análise de Correlação e Benchmark**
#
# ## **O Padrão de Mercado (Benchmark)**
# Ao analisar a matriz de correlação dos pares, foi possível observar:
# * **Ativo Total vs. Lucro Líquido (0.68):** A correlação é **Positiva Moderada**, e não Muito Forte.
# * **Insight:** O mercado premia a **Eficiência e o Nicho**. Um banco pode ter metade do Ativo de outro, mas gerar o mesmo Lucro se tiver spreads melhores e custos menores.
# * Isso confirma que, no ecossistema bancário médio brasileiro, **Modelo de Negócio > Tamanho**.
#
# ## **O Posicionamento do Banco Master**
# Ao analisar o Banco Master separadamente identifiquei uma divergência estratégica entre "Marca" e "Balanço":
#
# ### O Risco do "Yield de Varejo" com "Funding de Atacado"
# * O banco opera com **Custo de Capital de Banco Médio** mas precisa buscar **Retornos de Financeira de Crédito** para fechar a conta. Isso cria uma pressão estrutural por produtos de risco, explicando o alto volume de reclamações sobre "Cobrança Indevida" detectado na etapa de NLP.
#
# ### *Diferente da média do setor, que apresenta estabilidade na relação Capital/Tamanho, o Banco Master apresenta uma correlação inversa evidente, demonstrando uma fase de expansão de balanço financiada pelo aumento da alavancagem (consumo de índice de Basileia).*

# %%
colunas_visualizar = [
    'instituicao',
    'ativo_total',
    'lucro_liquido',
    'kpi_roe',
    'indice_basileia',
    'kpi_qualidade_lucro'
]

df_bancos = df_analitico.loc[df_analitico['instituicao'].isin(bancos_comparacao),colunas_visualizar].copy()


correlação_bancos = df_bancos.corr(
    method='pearson',
    numeric_only=True
)

plt.figure(figsize=(15,5))
sns.heatmap(
    correlação_bancos,
    annot=True,
    fmt=".2f",
    cmap='coolwarm',
    vmin=-1, vmax=1,
    center=0
)
plt.title('Correlação dos indicadores (Bancos em comparação)')
plt.show()

# %%
df_master = df_analitico.loc[df_analitico['instituicao'] == 'BANCO MASTER S/A',colunas_visualizar].copy()

correlação_master = df_master.corr(
    method='pearson',
    numeric_only=True
)

plt.figure(figsize=(15,5))
sns.heatmap(
    correlação_master,
    annot=True,
    fmt=".2f",
    cmap='coolwarm',
    vmin=-1, vmax=1,
    center=0
)
plt.title('Correlação dos indicadores (Banco Master)')
plt.show()

# %% [markdown]
# ## **Hipercrescimento do Ativo**
# Ao isolar a curva de Ativo Total, é possível notar uma inclinação muito superior à média do setor.
# * Esse comportamento é típico de **Crescimento Inorgânico**, realizado através da compra massiva de carteiras de crédito ou aquisição de outras instituições, e não pela captação tradicional no varejo.
#
# ## **Hipótese**
# Cruzando os dados com o contexto de mercado, o hipercrescimento do balanço sustenta a hipótese de preparação para um evento de liquidez (Aquisição):
# * Aumentar os Ativos melhora o *Valuation* e a relevância sistêmica da instituição em uma mesa de negociação.
#
# ## **Conclusão Final**
# O movimento de inflar o balanço seguido pela liquidação e intervenção feita pelo bacen em Novembro/2025, mostra um ciclo de **Tentativa de Saída Estratégica**. Os dados sugerem que o banco buscou ganhar indicadores rapidamente para se tornar atraente para um parceiro (como o BRB).

# %%
df_analitico['Trimestre'] = df_analitico['data_base'].dt.to_period('Q').astype(str)

df_bancos = df_analitico.loc[df_analitico['instituicao'].isin(bancos)].copy()

banco_foco = 'BANCO MASTER S/A'
todos_bancos = df_bancos['instituicao'].unique()

# Lógica para destacar o Banco Master na análise
paleta_cores = {banco: "#2E48DA" if banco == banco_foco else '#d9d9d9' for banco in todos_bancos}
espessuras = {banco: 4.0 if banco == banco_foco else 1.5 for banco in todos_bancos}

plt.figure(figsize=(15,8))

sns.lineplot(
    data=df_bancos,
    x='Trimestre',
    y='ativo_total',
    hue='instituicao',
    size='instituicao',
    palette=paleta_cores,
    sizes=espessuras
)

ax = plt.gca() # Pega o eixo atual
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.title('Evolução do Ativo Total', fontsize=16, fontweight='bold', loc='left', x=0.35)
plt.ylabel('Ativo Total (R$ Bilhões)')
plt.xlabel('Data Base')
plt.show()

# %% [markdown]
# # Custo de Funding: Comparação com o mercado
#
# ## O Benchmark de Eficiência (Linha Preta)
# A linha tracejada preta representa a taxa de **CDI**.
# * **Bancos Sólidos (Linhas Cinzas):** Note que a grande massa de bancos operam frequentemente **abaixo ou colada** à linha do CDI. Isso indica alta confiança do mercado e capacidade de captar recursos.
#
# ## A Ineficiência do Banco Master (Linha Azul)
# O Banco Master apresenta um comportamento divergente da média:
# * **Prêmio de Risco:** A linha azul opera consistentemente **acima do CDI**. Diferente dos pares que conseguem captar a 95% ou 100% do CDI, o Master frequentemente paga taxas superiores à Selic.
# * **Picos:** É possível observar momentos (como em 2023) onde o custo dispara, abrindo um spread significativo contra o mercado.
#
# ## Conclusão de Negócio
# Este gráfico prova que o dinheiro "custa mais caro" para o Master do que para seus concorrentes.
# * **Impacto na Margem:** Se o banco paga mais caro na entrada, ele entra no jogo do crédito com uma desvantagem competitiva.
# * **Obrigatoriedade do Risco:** Para manter a margem de lucro positiva pagando esse ágio no funding, a instituição não tem escolha a não ser operar em linhas de crédito de juros altíssimos (High Yield), que são inerentemente mais arriscadas. O funding caro é a raiz da estratégia agressiva do banco.

# %%
# Ordenar
# Sem isso, o shift(1) pode pegar dados de outro banco ou data errada
df_analitico = df_analitico.sort_values(['instituicao', 'data_base'])

# Lógica de Desacumulação
df_analitico['Despesa_Trimestre'] = df_analitico['Despesa_Captacao_Total']

mascara_acumulada = df_analitico['data_base'].dt.month.isin([6, 12])

# Aplica a subtração (Valor Atual - Valor do Trimestre Anterior)
df_analitico.loc[mascara_acumulada, 'Despesa_Trimestre'] = (
    df_analitico['Despesa_Captacao_Total'] - df_analitico['Despesa_Captacao_Total'].shift(1)
)

# Cálculos da Taxa
df_analitico['custo_funding_tri_real'] = (df_analitico['Despesa_Trimestre'] * -1) / df_analitico['captacoes']

# Anualização ((1+i)^4 - 1)
df_analitico['custo_funding_ano_real'] = ((1 + df_analitico['custo_funding_tri_real']) ** 4) - 1

# Atualizar df_bancos
df_bancos = df_analitico.loc[df_analitico['instituicao'].isin(bancos)].copy()
df_bancos = df_bancos.sort_values('Trimestre') # Garante a linha do tempo correta

cdi_historico = {
    '2021Q1': 0.019, '2021Q2': 0.032, '2021Q3': 0.050, '2021Q4': 0.077,
    '2022Q1': 0.101, '2022Q2': 0.121, '2022Q3': 0.139, '2022Q4': 0.134,
    '2023Q1': 0.136, '2023Q2': 0.132, '2023Q3': 0.135, '2023Q4': 0.118,
    '2024Q1': 0.109, '2024Q2': 0.105, '2024Q3': 0.110, '2024Q4': 0.111,
    '2025Q1': 0.125, '2025Q2': 0.140, '2025Q3': 0.157, '2025Q4': 0.109
}
# Mapear o CDI para dentro do df_bancos
df_bancos['taxa_cdi'] = df_bancos['Trimestre'].map(cdi_historico)

paleta_cores = {banco: "#2E48DA" if banco == banco_foco else '#d9d9d9' for banco in todos_bancos}
espessuras = {banco: 4.0 if banco == banco_foco else 1.5 for banco in todos_bancos}

plt.figure(figsize=(15,8))

sns.lineplot(
    data=df_bancos,
    x='Trimestre',
    y='custo_funding_ano_real',
    hue='instituicao',
    size='instituicao',
    palette=paleta_cores,
    sizes=espessuras
)

sns.lineplot(
    data=df_bancos, 
    x='Trimestre', 
    y='taxa_cdi', 
    color='black', 
    linestyle='--', 
    linewidth=2.5, 
    label='CDI (Ref. Mercado)',
    errorbar=None
)

ax.yaxis.set_major_formatter(ticker.PercentFormatter(1.0))

plt.title('Custo de Funding Bancos vs CDI (% a.a.)', fontsize=16, fontweight='bold', loc='left', x=0.25)
plt.ylabel('Taxa Anualizada (% a.a.)')
plt.xlabel('Trimestre')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# # **Correlação Crítica: (Funding x Basileia)**
#
# ## **O Diagnóstico de Basileia**
# É possível observar o **Índice de Basileia** do Banco Master operando próximo aos limites regulatórios mínimos, e descolado do benchmark, consequentemente uma fragilidade estrutural de capital. O banco possui pouco dinheiro em caixa para absorver descontroles.
#
# ## **A Precificação do Risco (Funding)**
# * A necessidade de oferecer taxas de captação muito acima é uma resposta direta à percepção de risco de basileia (Solvência). O banco paga caro não porque quer, mas porque precisa de liquidez imediata para girar a operação. Ou até mesmo relacionado a situação passada atualmente, buscando aumentar suas contas, para uma possível aquisição.
#
# ## **A Consequência Estratégica (High Yield Forçado)**
# * O perfil arriscado da carteira de crédito, e as reclamações decorrentes, não é uma"escolha comercial livre, mas sim uma **necessidade financeira de sobrevivência** imposta pela deterioração da solvência.

# %%
# Lógica para destacar o Banco Master na análise
paleta_cores = {banco: "#2E48DA" if banco == banco_foco else '#d9d9d9' for banco in todos_bancos}

plt.figure(figsize=(14, 6))

sns.barplot(
    data=df_bancos,
    x='Trimestre',
    y='indice_basileia',
    hue='instituicao',
    palette=paleta_cores
)

plt.title('Índice de Basileia vs. Mínimo Regulatório', fontsize=16, fontweight='bold', loc='left', x=0.25)
plt.ylabel('Índice de Basiléia')
plt.xlabel('Data Base')

# Linha de Perigo (Bancos costumam quebrar abaixo de 5-8% de capital próprio real)
plt.axhline(y=10.5, color='red', linestyle='--', linewidth=2, label='Zona de Perigo (<10.5%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

'''
A composição mínima é: (Fonte: BACEN)

8,0% (Mínimo Regulatório - Patrimônio de Referência)

2,5% (Adicional de Conservação de Capital - Buffer)

Total Efetivo: 10,5%

O que acontece se cair?

Abaixo de 10,5%: O banco ainda pode operar, mas sofre restrições automáticas (não pode distribuir dividendos acima do mínimo obrigatório, pagar bônus variáveis a executivos ou recomprar ações) até recompor o capital.

Abaixo de 8,0%: O banco entra em desconformidade grave, sujeito a intervenção ou liquidação pelo Banco Central.
'''
# Out:
# '\nA composição mínima é: (Fonte: BACEN)\n\n8,0% (Mínimo Regulatório - Patrimônio de Referência)\n\n2,5% (Adicional de Conservação de Capital - Buffer)\n\nTotal Efetivo: 10,5%\n\nO que acontece se cair?\n\nAbaixo de 10,5%: O banco ainda pode operar, mas sofre restrições automáticas (não pode distribuir dividendos acima do mínimo obrigatório, pagar bônus variáveis a executivos ou recomprar ações) até recompor o capital.\n\nAbaixo de 8,0%: O banco entra em desconformidade grave, sujeito a intervenção ou liquidação pelo Banco Central.\n'

# %% [markdown]
# # A Estratégia de Precificação
#
# ## O Diagnóstico Comparativo
# Ao comparar a métrica de **Yield (Receita de Juros / Carteira de Crédito)**, é possível observar uma grande de precificação:
# * **Benchmarks Conservadores (ABC, Pine):** trabalham com Yields baixos (~0.50), característicos de crédito corporativo (baixo risco, spreads apertados).
# * **Benchmarks de Varejo (Daycoval, Pan):** trabalham na faixa de 0.70 a 0.80, compatível com o mix de produtos financeiros.
# * **Banco Master:** Apresenta um Yield superior a **1.0 (100%+)**.
#
# ## A Correlação com a captação de crédito
# Este Yield agressivo não é necessariamente uma escolha de lucro extra, mas uma **necessidade de solvência (Basileia)**:
# * Na análise de Funding foi possível ver que o Master paga muito caro para captar dinheiro.
# * Se o custo do dinheiro é alto, o banco é obrigado a cobrar taxas abusivas na ponta final para manter um *Spread* positivo.
#
# ## Conclusão
# O banco atrai clientes dispostos a pagar taxas fora de mercado. Isso gera receita rápida no curto prazo, mas constrói uma carteira de crédito de baixa qualidade e alto risco de inadimplência e reclamações, confirmado pelo NLP.

# %%
# Lógica para destacar o Banco Master na análise
paleta_cores = {banco: "#2E48DA" if banco == banco_foco else '#d9d9d9' for banco in todos_bancos}

df_analitico['Year'] = df_analitico['data_base'].dt.year

df_bancos = df_analitico.loc[df_analitico['instituicao'].isin(bancos)].copy()

plt.figure(figsize=(15,7))

sns.barplot(
    data=df_bancos,
    x='Trimestre',
    y='yield_carteira',
    hue='instituicao',
    palette=paleta_cores,
    errorbar=None
)


ax = plt.gca()
plt.gca().yaxis.set_major_formatter(ticker.PercentFormatter(1.0))
plt.title('Evolução do Yield de juros cobrados', fontsize=16, fontweight='bold', loc='left', x=0.35)
plt.ylabel('Yield')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# # **Análise de Qualidade do Lucro**
#
# ## **O Teste da máscara contábil**
# Ao cruzar o **ROE** com a dependência de **Outras Receitas**, busquei identificar se a rentabilidade do banco é sustentável ou vinda de  Eventos não-recorrentes.
#
# ## **A conclusão com Dados**
# * O Banco Master apresenta uma correlação saudável neste aspecto. O Master mostra uma dependência controlada de "Outras Receitas".
# * **Diagnóstico:** O lucro é **Operacional**. A rentabilidade elevada (ROE) vêm de maioria pela atividade de Intermediação Financeira/Crédito.
#
# ## **Conclusão Final**
# O risco do Banco Master não é contábil (fraude de balanço), é  **Operacional e de Crédito**. A instituição é uma máquina de juros eficiente, transferindo o custo de captação para o cliente final. O perigo está na sustentabilidade da carteira: clientes dispostos a pagar taxas tão altas possuem pior score de crédito, tornando o banco sensível a aumento de inadimplência.

# %%
plt.figure(figsize=(15, 8))

# Lógica para destacar o Banco Master na análise
paleta_cores = {banco: "#2E48DA" if banco == banco_foco else '#d9d9d9' for banco in todos_bancos}
espessuras = {banco: 4.0 if banco == banco_foco else 1.5 for banco in todos_bancos}

sns.scatterplot(
    data=df_bancos,
    x='kpi_qualidade_lucro',
    y='kpi_roe',
    hue='instituicao',
    size='ativo_total',
    sizes=(50, 600),
    alpha=0.7,
    palette=paleta_cores
)

# Eixo Y: ROE Trimestral de ~3.75% (equivale a ~15% anual)
plt.axhline(y=0.0375, color='green', linestyle='--', alpha=0.6, label='ROE Alvo (3.75% tri / ~15% ano)')
# Eixo X: Alerta se +20% da receita for não-core
plt.axvline(x=0.20, color='red', linestyle='--', alpha=0.6, label='Alerta: +20% Receita Não-Op.')

plt.title('Matriz de Qualidade: Sólido vs. Artificial', fontsize=16, fontweight='bold', loc='left', x=0.27)
plt.ylabel('ROE (Rentabilidade)')
plt.xlabel('Dependência de "Outras Receitas"')

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
